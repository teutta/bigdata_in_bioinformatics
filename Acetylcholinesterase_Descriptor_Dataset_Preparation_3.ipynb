# %% [markdown]
# <a href="https://colab.research.google.com/github/teutta/bigdata_in_bioinformatics/blob/main/Acetylcholinesterase_Descriptor_Dataset_Preparation_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Në këtë pjesë, ne do të llogarisim përshkruesit molekularë që janë në thelb përshkrim sasior i komponimeve në grupin e të 
# dhënave. Në fund, ne do ta përgatisim këtë në një grup të dhënash për ndërtimin e modelit pasues në pjesën tjetër.
# Ne do të fillojmë me shkarkimin e PaDEL-Descriptor:

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Out:
# --2022-02-02 23:52:09--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip [following]
# --2022-02-02 23:52:09--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip.1’
#
# padel.zip.1         100%[===================>]  24.57M  --.-KB/s    in 0.1s
#
# 2022-02-02 23:52:09 (167 MB/s) - ‘padel.zip.1’ saved [25768637/25768637]
#
# ...

# %%
! unzip padel.zip
# Out:
# Archive:  padel.zip
#    creating: PaDEL-Descriptor/
#   inflating: __MACOSX/._PaDEL-Descriptor
#   inflating: PaDEL-Descriptor/MACCSFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._MACCSFingerprinter.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprinter.xml
#   inflating: PaDEL-Descriptor/EStateFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._EStateFingerprinter.xml
#   inflating: PaDEL-Descriptor/Fingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._Fingerprinter.xml
#   inflating: PaDEL-Descriptor/.DS_Store
#   inflating: __MACOSX/PaDEL-Descriptor/._.DS_Store
#    creating: PaDEL-Descriptor/license/
#   inflating: __MACOSX/PaDEL-Descriptor/._license
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprintCount.xml
#   inflating: PaDEL-Descriptor/config
# ...

# %%
# Këtu do të përdorim file-in bioactivity_data_3class_pIC50.csv që përmban vlerat pIC50 të cilat do ti përdorim për ndërtimin 
# e një modeli regresioni.

# %%
! wget https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv
# Out:
# --2022-02-02 23:53:14--  https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 655414 (640K) [text/plain]
# Saving to: ‘acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv.1’
#
# acetylcholinesteras 100%[===================>] 640.05K  --.-KB/s    in 0.04s
#
# 2022-02-02 23:53:14 (14.6 MB/s) - ‘acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv.1’ saved [655414/655414]

# %% [markdown]
# # New Section

# %%
# Në vazhdim do të importojmë pandas përmes së cilës do të shfaqim të dhënat nga file 
# acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv

# %%
import pandas as pd

# %%
df3 = pd.read_csv('acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv')

# %%
df3
# Out:
#       Unnamed: 0 molecule_chembl_id  ... NumHAcceptors     pIC50
# 0              0       CHEMBL133897  ...           6.0  6.124939
# 1              1       CHEMBL336398  ...           5.0  7.000000
# 2              2       CHEMBL131588  ...           5.0  4.301030
# 3              3       CHEMBL130628  ...           5.0  6.522879
# 4              4       CHEMBL130478  ...           6.0  6.096910
# ...          ...                ...  ...           ...       ...
# 4690        4690      CHEMBL4293155  ...           3.0  5.612610
# 4691        4691      CHEMBL4282558  ...           3.0  5.595166
# 4692        4692      CHEMBL4281727  ...           3.0  5.419075
# 4693        4693      CHEMBL4292349  ...           5.0  5.460924
# 4694        4694      CHEMBL4278260  ...           4.0  5.555955
#
# [4695 rows x 9 columns]

# %%
# Nga të dhënat e mësipërme zgjedhim vetëm kolonat canonical_smiles dhe molecule_chembl_id dhe i ruajmë në file-in molecule.smi

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df3_selection = df3[selection]
df3_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
# E shfaqim file-in molecule.smi

# %%
! cat molecule.smi | head -5
# Out:
# CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1	CHEMBL133897
# O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1	CHEMBL336398
# CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1	CHEMBL131588
# O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F	CHEMBL130628
# CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C	CHEMBL130478

# %%
# Numërojmë numrin e rreshtave të të dhënave në molecule.smi për ta krahasuar me numrin e rreshtave nga të dhënat e tabelës 
# fillestare (rezulton se është i njejtë).

# %%
! cat molecule.smi | wc -l
# Out:
# 4695

# %%
# Kalkulojmë përshkruesit duke bërë run bash padel.sh
# Fillimisht shfaqim përmbajtjen e padel.sh

# %%
! cat padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
! bash padel.sh
# Out:
# Processing CHEMBL241960 in molecule.smi (1255/4695). Average speed: 0.18 s/mol.
# Processing CHEMBL557586 in molecule.smi (1254/4695). Average speed: 0.18 s/mol.
# Processing CHEMBL241974 in molecule.smi (1256/4695). Average speed: 0.18 s/mol.
# Processing CHEMBL390247 in molecule.smi (1258/4695). Average speed: 0.18 s/mol.
# Processing CHEMBL244762 in molecule.smi (1257/4695). Average speed: 0.18 s/mol.
# Processing CHEMBL276444 in molecule.smi (1259/4695). Average speed: 0.18 s/mol.
# Processing CHEMBL395815 in molecule.smi (1260/4695). Average speed: 0.18 s/mol.
# Processing CHEMBL243057 in molecule.smi (1261/4695). Average speed: 0.18 s/mol.
# Processing CHEMBL243274 in molecule.smi (1262/4695). Average speed: 0.18 s/mol.
# Processing CHEMBL394865 in molecule.smi (1263/4695). Average speed: 0.18 s/mol.
# Processing CHEMBL242661 in molecule.smi (1264/4695). Average speed: 0.18 s/mol.
# Processing CHEMBL218443 in molecule.smi (1265/4695). Average speed: 0.18 s/mol.
# ...

# %%
# Kalkulimi i mësipërm merr shumë kohë (18-19 min) prandaj importojmë të dhënat e fituara të gatshme nga descriptors_output.csv

# %%
! ls -l
# Out:
# total 54164
# -rw-r--r-- 1 root root   655414 Feb  2 23:51 acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv
# -rw-r--r-- 1 root root   655414 Feb  2 23:53 acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv.1
# -rw-r--r-- 1 root root  2266149 Feb  2 23:57 descriptors_output.csv
# drwxr-xr-x 3 root root     4096 Feb  2 23:52 __MACOSX
# -rw-r--r-- 1 root root   310658 Feb  2 23:53 molecule.smi
# drwxrwxr-x 4 root root     4096 May 30  2020 PaDEL-Descriptor
# -rw-r--r-- 1 root root      231 Feb  2 23:50 padel.sh
# -rw-r--r-- 1 root root      231 Feb  2 23:52 padel.sh.1
# -rw-r--r-- 1 root root 25768637 Feb  2 23:50 padel.zip
# -rw-r--r-- 1 root root 25768637 Feb  2 23:52 padel.zip.1
# drwxr-xr-x 1 root root     4096 Feb  1 14:32 sample_data

# %%
# Shfaqim të dhënat nga descriptors_output.csv dhe ndërtojmë matricën XY të të dhënave, duke filluar me matricën X:

# %%
df3_X = pd.read_csv('descriptors_output.csv')

# %%
df3_X
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0              1           1  ...             0             0
# 1              1           1  ...             0             0
# 2              1           1  ...             0             0
# 3              1           1  ...             0             0
# 4              1           1  ...             0             0
# ...          ...         ...  ...           ...           ...
# 1264           1           1  ...             0             0
# 1265           1           1  ...             0             0
# 1266           1           1  ...             0             0
# 1267           1           1  ...             0             0
# 1268           1           1  ...             0             0
#
# [1269 rows x 881 columns]

# %%
# Largojmë kolonën Name nga tabela sepse na nevojiten vetëm veçoritë e molekulave

# %%
df3_X = df3_X.drop(columns=['Name'])
df3_X
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-16dc25c104cb> in <module>()
# ----> 1 df3_X = df3_X.drop(columns=['Name'])
#       2 df3_X
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %%
# Ndërtojmë matricën Y duke zgjedhur kolonën pIC50 nga df3

# %%
df3_Y = df3['pIC50']
df3_Y
# Out:
# 0       6.124939
# 1       7.000000
# 2       4.301030
# 3       6.522879
# 4       6.096910
#           ...
# 4690    5.612610
# 4691    5.595166
# 4692    5.419075
# 4693    5.460924
# 4694    5.555955
# Name: pIC50, Length: 4695, dtype: float64

# %%
# I kombinojmë matricat X dhe Y

# %%
dataset3 = pd.concat([df3_X,df3_Y], axis=1)
dataset3
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0            1.0         1.0         1.0  ...           0.0           0.0  6.124939
# 1            1.0         1.0         1.0  ...           0.0           0.0  7.000000
# 2            1.0         1.0         1.0  ...           0.0           0.0  4.301030
# 3            1.0         1.0         0.0  ...           0.0           0.0  6.522879
# 4            1.0         1.0         0.0  ...           0.0           0.0  6.096910
# ...          ...         ...         ...  ...           ...           ...       ...
# 4690         NaN         NaN         NaN  ...           NaN           NaN  5.612610
# 4691         NaN         NaN         NaN  ...           NaN           NaN  5.595166
# 4692         NaN         NaN         NaN  ...           NaN           NaN  5.419075
# 4693         NaN         NaN         NaN  ...           NaN           NaN  5.460924
# ...

# %%
# Matricën XY të fituar të të dhënave e nxjerrim si csv file.

# %%
dataset3.to_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv', index=False)
